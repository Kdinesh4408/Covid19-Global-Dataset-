# %% [markdown]
# # ***Covid-19 Global Dataset***
#
#  **1.Which highest continent spread COVID-19**
#
#  **2.Comparison between confirmed,deaths,total_recovered and active cases with continent**
#
#  **3.Analysis continent according total cases per 1m population**
#
#  **4.continent according total deat per 1m population**
#
#  **5.Comparison between total deat hs per 1m population and total cases per 1m population with country**
#
#  **6.Analysis Country according total tests**
#
#  **7.Comparison between population and total tests**
#
#  **8.Which continent highest cases in percentage**
#
#  **9.EDA**
#
#  **10.BIVARIANT ANALYSIS**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ad = pd.read_csv(r"F:\DOWNLOADS\Covid-19 Global Dataset\worldometer_coronavirus_summary_data.csv")

# %%
ad
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# ...

# %%
ad.columns
# Out:
# Index(['country', 'continent', 'total_confirmed', 'total_deaths',
#        'total_recovered', 'active_cases', 'serious_or_critical',
#        'total_cases_per_1m_population', 'total_deaths_per_1m_population',
#        'total_tests', 'total_tests_per_1m_population', 'population'],
#       dtype='object')

# %%
ad.describe(include='all')
# Out:
#             country continent  total_confirmed  total_deaths  total_recovered  \
# count           226       226     2.260000e+02  2.180000e+02     2.040000e+02
# unique          226         6              NaN           NaN              NaN
# top     Afghanistan    Africa              NaN           NaN              NaN
# freq              1        58              NaN           NaN              NaN
# mean            NaN       NaN     2.305651e+06  2.884442e+04     2.256851e+06
# std             NaN       NaN     7.575510e+06  9.971254e+04     7.613357e+06
# min             NaN       NaN     2.000000e+00  1.000000e+00     1.000000e+00
# 25%             NaN       NaN     2.412600e+04  2.370000e+02     1.619300e+04
# 50%             NaN       NaN     1.793750e+05  2.251500e+03     1.372740e+05
# 75%             NaN       NaN     1.090902e+06  1.400650e+04     1.006245e+06
# max             NaN       NaN     8.420947e+07  1.026646e+06     8.124426e+07
#
# ...

# %%
ad.dropna(how='any',inplace=True)
ad.isnull().sum()
# Out:
# country                           0
# continent                         0
# total_confirmed                   0
# total_deaths                      0
# total_recovered                   0
# active_cases                      0
# serious_or_critical               0
# total_cases_per_1m_population     0
# total_deaths_per_1m_population    0
# total_tests                       0
# total_tests_per_1m_population     0
# population                        0
# dtype: int64

# %%
ad.head()
# Out:
#        country      continent  total_confirmed  total_deaths  total_recovered  \
# 0  Afghanistan           Asia           179267        7690.0         162202.0
# 1      Albania         Europe           275574        3497.0         271826.0
# 2      Algeria         Africa           265816        6875.0         178371.0
# 3      Andorra         Europe            42156         153.0          41021.0
# 5     Anguilla  North America             2984           9.0           2916.0
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0        9375.0               1124.0                           4420
# 1         251.0                  2.0                          95954
# 2       80570.0                  6.0                           5865
# 3         982.0                 14.0                         543983
# 5          59.0                  4.0                         195646
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# ...

# %%
ad.tail()
# Out:
#         country      continent  total_confirmed  total_deaths  \
# 217  Uzbekistan           Asia           238802        1637.0
# 219   Venezuela  South America           522921        5711.0
# 220    Viet Nam           Asia         10696630       43065.0
# 223       Yemen           Asia            11819        2149.0
# 225    Zimbabwe         Africa           249206        5482.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 217         236974.0         191.0                 23.0
# 219         516170.0        1040.0                230.0
# 220        9355040.0     1298525.0                340.0
# 223           9009.0         661.0                 23.0
# 225         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 217                           6947                            48.0
# 219                          18487                           202.0
# ...

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131 entries, 0 to 225
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         131 non-null    object
#  1   continent                       131 non-null    object
#  2   total_confirmed                 131 non-null    int64
#  3   total_deaths                    131 non-null    float64
#  4   total_recovered                 131 non-null    float64
#  5   active_cases                    131 non-null    float64
#  6   serious_or_critical             131 non-null    float64
#  7   total_cases_per_1m_population   131 non-null    int64
#  8   total_deaths_per_1m_population  131 non-null    float64
#  9   total_tests                     131 non-null    float64
#  10  total_tests_per_1m_population   131 non-null    float64
#  11  population                      131 non-null    int64
# ...

# %%
ad.isnull().sum()
# Out:
# country                           0
# continent                         0
# total_confirmed                   0
# total_deaths                      0
# total_recovered                   0
# active_cases                      0
# serious_or_critical               0
# total_cases_per_1m_population     0
# total_deaths_per_1m_population    0
# total_tests                       0
# total_tests_per_1m_population     0
# population                        0
# dtype: int64

# %%
ad.rename(columns={'total_deaths':'deaths','listed_in(type)':'Type'},inplace=True)
ad.rename(columns={'active_cases':'active cases','listed_in(type)':'Type'},inplace=True)
ad.rename(columns={'total_cases_per_1m_population':'total cases per 1m population','listed_in(type)':'Type'},inplace=True)
ad.rename(columns={'total_deaths_per_1m_population':'total deat hs per 1m population','listed_in(type)':'Type'},inplace=True)
ad.rename(columns={'total_tests':'total tests','listed_in(type)':'Type'},inplace=True)
ad.rename(columns={'total_tests_per_1m_population':'total tests per 1m population','listed_in(type)':'Type'},inplace=True)
ad.rename(columns={'total_confirmed':'confirmed','listed_in(type)':'Type'},inplace=True)
ad.rename(columns={'serious_or_critical':'serious','listed_in(type)':'Type'},inplace=True)

# %%
ad.head()
# Out:
#        country      continent  confirmed  deaths  total_recovered  \
# 0  Afghanistan           Asia     179267  7690.0         162202.0
# 1      Albania         Europe     275574  3497.0         271826.0
# 2      Algeria         Africa     265816  6875.0         178371.0
# 3      Andorra         Europe      42156   153.0          41021.0
# 5     Anguilla  North America       2984     9.0           2916.0
#
#    active cases  serious  total cases per 1m population  \
# 0        9375.0   1124.0                           4420
# 1         251.0      2.0                          95954
# 2       80570.0      6.0                           5865
# 3         982.0     14.0                         543983
# 5          59.0      4.0                         195646
#
#    total deat hs per 1m population  total tests  \
# 0                            190.0     951337.0
# 1                           1218.0    1817530.0
# 2                            152.0     230861.0
# ...

# %% [markdown]
# # DATA CLEANING

# %%
ad.dtypes
# Out:
# country                             object
# continent                           object
# confirmed                            int64
# deaths                             float64
# total_recovered                    float64
# active cases                       float64
# serious                            float64
# total cases per 1m population        int64
# total deat hs per 1m population    float64
# total tests                        float64
# total tests per 1m population      float64
# population                           int64
# dtype: object

# %%
a=ad['country'].unique()
print(a)
print('----------------------------------------------------------------------')
b=ad['continent'].unique()
print(b)
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'Andorra' 'Anguilla'
#  'Antigua And Barbuda' 'Argentina' 'Australia' 'Austria' 'Bahrain'
#  'Bangladesh' 'Belgium' 'Belize' 'Benin' 'Bolivia' 'Botswana' 'Brazil'
#  'Bulgaria' 'Cabo Verde' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chile' 'China' 'Colombia' 'Costa Rica'
#  'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czech Republic' 'Denmark'
#  'Dominican Republic' 'Egypt' 'El Salvador' 'Equatorial Guinea' 'Estonia'
#  'Ethiopia' 'Faeroe Islands' 'France' 'French Guiana' 'Germany' 'Ghana'
#  'Greece' 'Greenland' 'Grenada' 'Guadeloupe' 'Guatemala' 'Guinea Bissau'
#  'Guinea' 'Honduras' 'Hungary' 'India' 'Indonesia' 'Iran' 'Iraq' 'Ireland'
#  'Israel' 'Italy' 'Japan' 'Jordan' 'Kazakhstan' 'Kuwait' 'Kyrgyzstan'
#  'Latvia' 'Lebanon' 'Liberia' 'Libya' 'Liechtenstein' 'Lithuania'
#  'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Malta' 'Martinique' 'Mexico'
#  'Moldova' 'Monaco' 'Mongolia' 'Montenegro' 'Morocco' 'Mozambique'
# ...

# %%
ad['confirmed']=ad['confirmed'].astype(str)
ad['confirmed']=ad['confirmed'].apply(lambda x:x.replace(',','.'))
ad['confirmed']=ad['confirmed'].astype(float)
ad['confirmed'].head()
# Out:
# 0    179267.0
# 1    275574.0
# 2    265816.0
# 3     42156.0
# 5      2984.0
# Name: confirmed, dtype: float64

# %%
#ad['continent']=ad['continent'].map({'Asia':'A','Europe':'B','Africa':'C', 'North America':'D', 'South America':'E',
 #'Australia/Oceania':'F'})
ad
# Out:
#          country      continent   confirmed   deaths  total_recovered  \
# 0    Afghanistan           Asia    179267.0   7690.0         162202.0
# 1        Albania         Europe    275574.0   3497.0         271826.0
# 2        Algeria         Africa    265816.0   6875.0         178371.0
# 3        Andorra         Europe     42156.0    153.0          41021.0
# 5       Anguilla  North America      2984.0      9.0           2916.0
# ..           ...            ...         ...      ...              ...
# 217   Uzbekistan           Asia    238802.0   1637.0         236974.0
# 219    Venezuela  South America    522921.0   5711.0         516170.0
# 220     Viet Nam           Asia  10696630.0  43065.0        9355040.0
# 223        Yemen           Asia     11819.0   2149.0           9009.0
# 225     Zimbabwe         Africa    249206.0   5482.0         242417.0
#
#      active cases  serious  total cases per 1m population  \
# 0          9375.0   1124.0                           4420
# ...

# %%
ad.shape
# Out:
# (131, 12)

# %%
ad.size
# Out:
# 1572

# %%
ad.describe()
# Out:
#           confirmed        deaths  total_recovered  active cases      serious  \
# count  1.310000e+02  1.310000e+02     1.310000e+02  1.310000e+02   131.000000
# mean   3.578809e+06  4.275371e+04     3.437406e+06  9.864927e+04   284.435115
# std    9.624057e+06  1.250529e+05     9.302725e+06  2.826380e+05   925.882607
# min    2.739000e+03  1.000000e+00     1.040000e+02  2.500000e+01     1.000000
# 25%    6.796700e+04  6.765000e+02     5.618700e+04  6.655000e+02     5.000000
# 50%    5.169860e+05  5.711000e+03     5.041420e+05  6.141000e+03    15.000000
# 75%    2.740780e+06  2.345250e+04     2.719056e+06  5.677200e+04   135.000000
# max    8.420947e+07  1.026646e+06     8.124426e+07  1.938567e+06  8318.000000
#
#        total cases per 1m population  total deat hs per 1m population  \
# count                     131.000000                       131.000000
# mean                   174161.748092                      1306.847328
# ...

# %%
ad.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 5      False
#        ...
# 217    False
# 219    False
# 220    False
# 223    False
# 225    False
# Length: 131, dtype: bool

# %%
ad.head()
# Out:
#        country      continent  confirmed  deaths  total_recovered  \
# 0  Afghanistan           Asia   179267.0  7690.0         162202.0
# 1      Albania         Europe   275574.0  3497.0         271826.0
# 2      Algeria         Africa   265816.0  6875.0         178371.0
# 3      Andorra         Europe    42156.0   153.0          41021.0
# 5     Anguilla  North America     2984.0     9.0           2916.0
#
#    active cases  serious  total cases per 1m population  \
# 0        9375.0   1124.0                           4420
# 1         251.0      2.0                          95954
# 2       80570.0      6.0                           5865
# 3         982.0     14.0                         543983
# 5          59.0      4.0                         195646
#
#    total deat hs per 1m population  total tests  \
# 0                            190.0     951337.0
# 1                           1218.0    1817530.0
# 2                            152.0     230861.0
# ...

# %% [markdown]
# # DATA VISULIZATION :

# %% [markdown]
# # 1.Which highest continent spread COVID-19

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.countplot(x='continent',data=ad,ax=ax,color='darkred')
for i in ax.containers:
    ax.bar_label(i)
plt.title('Highest Continent')
# Out:
# Text(0.5, 1.0, 'Highest Continent')

# %% [markdown]
# # 2.Comparison between confirmed,deaths,total_recovered and active cases with continent

# %%
ad2=ad[['confirmed','deaths','total_recovered','active cases','continent']]
ad2
# Out:
#       confirmed   deaths  total_recovered  active cases      continent
# 0      179267.0   7690.0         162202.0        9375.0           Asia
# 1      275574.0   3497.0         271826.0         251.0         Europe
# 2      265816.0   6875.0         178371.0       80570.0         Africa
# 3       42156.0    153.0          41021.0         982.0         Europe
# 5        2984.0      9.0           2916.0          59.0  North America
# ..          ...      ...              ...           ...            ...
# 217    238802.0   1637.0         236974.0         191.0           Asia
# 219    522921.0   5711.0         516170.0        1040.0  South America
# 220  10696630.0  43065.0        9355040.0     1298525.0           Asia
# 223     11819.0   2149.0           9009.0         661.0           Asia
# 225    249206.0   5482.0         242417.0        1307.0         Africa
#
# [131 rows x 5 columns]

# %%
sns.pairplot(ad2,hue='continent',height=2.5)

# %% [markdown]
# # 3.Analysis continent according total cases per 1m population

# %%
plt.subplots(figsize=(10,6))
sns.boxplot(x=ad['continent'],y=ad['total cases per 1m population'],palette='rainbow')
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_1916\3805924267.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=ad['continent'],y=ad['total cases per 1m population'],palette='rainbow')
# <Axes: xlabel='continent', ylabel='total cases per 1m population'>

# %% [markdown]
# # 4.continent according total deat per 1m population

# %%
plt.subplots(figsize=(14,6))
sns.barplot(x=ad['total deat hs per 1m population'],y=ad['continent'],color='r')
plt.show()

# %%
ad.head()
# Out:
#        country      continent  confirmed  deaths  total_recovered  \
# 0  Afghanistan           Asia   179267.0  7690.0         162202.0
# 1      Albania         Europe   275574.0  3497.0         271826.0
# 2      Algeria         Africa   265816.0  6875.0         178371.0
# 3      Andorra         Europe    42156.0   153.0          41021.0
# 5     Anguilla  North America     2984.0     9.0           2916.0
#
#    active cases  serious  total cases per 1m population  \
# 0        9375.0   1124.0                           4420
# 1         251.0      2.0                          95954
# 2       80570.0      6.0                           5865
# 3         982.0     14.0                         543983
# 5          59.0      4.0                         195646
#
#    total deat hs per 1m population  total tests  \
# 0                            190.0     951337.0
# 1                           1218.0    1817530.0
# 2                            152.0     230861.0
# ...

# %% [markdown]
# # 5.Comparison between total deat hs per 1m population and total cases per 1m population with country

# %%
ad3 = ad[['total deat hs per 1m population','total cases per 1m population','country']]
ad3.head()
# Out:
#    total deat hs per 1m population  total cases per 1m population      country
# 0                            190.0                           4420  Afghanistan
# 1                           1218.0                          95954      Albania
# 2                            152.0                           5865      Algeria
# 3                           1974.0                         543983      Andorra
# 5                            590.0                         195646     Anguilla

# %%
sns.pairplot(ad3,hue='country',height=2.5)

# %% [markdown]
# # 6.Analysis Country according total tests

# %%
plt.subplots(figsize=(10,20))
sns.barplot(x='total tests',y='country',data=ad,palette='rainbow')
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_1916\319949133.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='total tests',y='country',data=ad,palette='rainbow')
# <Axes: xlabel='total tests', ylabel='country'>

# %% [markdown]
# # 7.Comparison between population and total tests

# %%
plt.subplots(figsize=(25,6))
ax=sns.swarmplot(x=ad['population'],y=ad['total tests'],color='brown')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_1916\326213664.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, '5741'),
#  Text(1, 0, '15252'),
#  Text(2, 0, '18255'),
#  Text(3, 0, '34064'),
#  Text(4, 0, '38332'),
#  Text(5, 0, '39692'),
#  Text(6, 0, '39760'),
#  Text(7, 0, '39894'),
#  Text(8, 0, '43783'),
#  Text(9, 0, '49209'),
#  Text(10, 0, '56953'),
#  Text(11, 0, '67159'),
#  Text(12, 0, '77495'),
#  Text(13, 0, '99439'),
#  Text(14, 0, '113494'),
#  Text(15, 0, '165343'),
#  Text(16, 0, '185190'),
#  Text(17, 0, '200869'),
#  Text(18, 0, '290610'),
#  Text(19, 0, '313094'),
#  Text(20, 0, '374723'),
#  Text(21, 0, '400251'),
#  Text(22, 0, '411069'),
#  Text(23, 0, '443733'),
#  Text(24, 0, '558272'),
#  Text(25, 0, '567234'),
#  Text(26, 0, '628214'),
#  Text(27, 0, '718243'),
#  Text(28, 0, '907212'),
# ...

# %% [markdown]
# # 8.Which continent highest cases in percentage

# %%
ad.groupby('continent')['country'].count().nlargest(8).plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='country'>

# %% [markdown]
# # 9.EDA

# %%
ad.hist(figsize=(25,20),color='olive')
# Out:
# array([[<Axes: title={'center': 'confirmed'}>,
#         <Axes: title={'center': 'deaths'}>,
#         <Axes: title={'center': 'total_recovered'}>],
#        [<Axes: title={'center': 'active cases'}>,
#         <Axes: title={'center': 'serious'}>,
#         <Axes: title={'center': 'total cases per 1m population'}>],
#        [<Axes: title={'center': 'total deat hs per 1m population'}>,
#         <Axes: title={'center': 'total tests'}>,
#         <Axes: title={'center': 'total tests per 1m population'}>],
#        [<Axes: title={'center': 'population'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # 10.BIVARIANT ANALYSIS

# %%
sns.pairplot(ad)
